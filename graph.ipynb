# %%
import pandas as pd                
import matplotlib as mpl          
import matplotlib.pyplot as plt    

# csv 파일을 읽어서 DataFrame 객체로 만듦. 인덱스 컬럼은 point로 설정
# corporation_information_filename = 'corporation_information.csv'
corporation_information_filename = 'corporation_information.csv'
df = pd.read_csv(corporation_information_filename, index_col='종목코드', encoding='utf-8')


# Windows 한글 폰트 설정
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

# %%
df = df[["회사명","기업가치","시가총액","안전마진율"]]
df = df.sort_values(by='안전마진율', ascending=False)
df
# Out:
#              회사명             기업가치            시가총액        안전마진율
# 종목코드
# 31980      피에스케이    1085841890000     47400000000  2190.805675
# 4960        한신공영    2516147980000    208300000000  1107.944301
# 33160      엠케이전자    2042646880000    171400000000  1091.742637
# 54800    아이디스홀딩스    1077338490000    139200000000   673.950065
# 12320     경동인베스트     689704840000     90700000000   660.424300
# 36530     S&T홀딩스    1421329230000    199700000000   611.732213
# 9200       무림페이퍼     929580490000    131700000000   605.831807
# 13580     계룡건설산업    1688143750000    246500000000   584.845335
# 29460        케이씨    1314874380000    194500000000   576.027959
# 5450          신한     225508280000     34700000000   549.879769
# 1940    KISCO홀딩스    1632274040000    253100000000   544.912699
# 2030         아세아    1627216570000    254200000000   540.132404
# 45100      한양이엔지    1428833680000    227700000000   527.507106
# 36000        예림당     685281660000    114500000000   498.499266
# ...

# %%
ax = df.plot(kind='bar', title='기업가치와 안전마진', figsize=(20, 4), legend=True, fontsize=12)
ax.set_xlabel('기업', fontsize=12)          # x축 정보 표시
ax.set_ylabel('기온/습도', fontsize=12)     # y축 정보 표시
ax.legend(['기온', '습도','00'], fontsize=12)    # 범례 지정
plt.show()

# %%
margin_df = df[["회사명","안전마진율"]]
margin_df = margin_df.set_index("회사명")
margin_df
ax = margin_df.plot(kind='bar', figsize=(20, 7), title='기업별 안전마진율', legend=True, fontsize=1)
ax.legend(['안전마진율(%)'], fontsize=12)    # 범례 지정

# %%
value_df = df[["회사명", "기업가치", "시가총액"]]
value_df = value_df.set_index("회사명")
value_df = value_df.sort_values(by='기업가치', ascending=False)
value_df
# Out:
#                           기업가치             시가총액
# 회사명
# 삼성전자           861887034800000  254014200000000
# 에스케이하이닉스       281418799920000   47975400000000
# 포스코             75684753350000   20445300000000
# 현대모비스           45902794060000   20681600000000
# SK              43963581820000   16816100000000
# LG              39774212910000   12458600000000
# SK이노베이션         28802487330000   14887000000000
# 롯데케미칼           28691134900000    8843100000000
# LG화학            28653712140000   23013100000000
# LG전자            27987119890000   12682700000000
# 삼성물산            26476790010000   17755000000000
# GS              26008801060000    4641100000000
# 케이티앤지           21161256780000   13646900000000
# 기아자동차           19958103190000   16579400000000
# 네이버             15476907020000   17882300000000
# SK텔레콤           15429898470000   20469000000000
# 삼성SDS           15299193960000   15785100000000
# 삼성SDI           14660010920000   14337400000000
# ...

# %%
high_value_df = value_df.iloc[:10]
print(type(df))
print(type(high_value_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
high_value_df = value_df.iloc[:50]
high_value_df
# Out:
#                        기업가치             시가총액
# 회사명
# 삼성전자        861887034800000  254014200000000
# 에스케이하이닉스    281418799920000   47975400000000
# 포스코          75684753350000   20445300000000
# 현대모비스        45902794060000   20681600000000
# SK           43963581820000   16816100000000
# LG           39774212910000   12458600000000
# SK이노베이션      28802487330000   14887000000000
# 롯데케미칼        28691134900000    8843100000000
# LG화학         28653712140000   23013100000000
# LG전자         27987119890000   12682700000000
# 삼성물산         26476790010000   17755000000000
# GS           26008801060000    4641100000000
# 케이티앤지        21161256780000   13646900000000
# 기아자동차        19958103190000   16579400000000
# 네이버          15476907020000   17882300000000
# SK텔레콤        15429898470000   20469000000000
# 삼성SDS        15299193960000   15785100000000
# 삼성SDI        14660010920000   14337400000000
# LG생활건강       13499788930000   19663300000000
# 고려아연         13460204100000    8217900000000
# ...

# %%
# high_value_df = high_value_df.set_index("회사명")
#for name, value in high_value_df.iterrows():
#    print(value['기업가치'] / 1000000)
#    print(high_value_df[name])
#    high_value_df[name]['기업가치'] = value['기업가치'] / 1000000
#    high_value_df[name]['시가총액'] = value['시가총액'] / 1000000
ax = high_value_df.plot(kind='bar', figsize=(20, 10), title='기업별 가치 - 기업가치순', legend=True, fontsize=12)
ax.legend(['기업가치(원)', '시가총액(원)'], fontsize=12)    # 범례 지정

# %%
high_price_df = value_df.sort_values(by='시가총액', ascending=False).iloc[:50]
ax = high_price_df.plot(kind='bar', figsize=(20, 10), title='기업별 가치-시가총액순', legend=True, fontsize=12)
ax.legend(['기업가치(원)', '시가총액(원)'], fontsize=12)    # 범례 지정

# %%
high_margin_df = margin_df.iloc[:100]
ax = high_margin_df.plot(kind='bar', figsize=(20, 10), title='기업별 안전마진율', legend=True, fontsize=12)
ax.legend(['안전마진율(%)'], fontsize=12)    # 범례 지정
